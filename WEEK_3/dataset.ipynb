# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a0518/NASSCOM/blob/main/WEEK_3_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("/content/dataset - Sheet1.csv")
df.head()
# Out:
#    s.no  Rollno       name  age
# 0     1     501    pranavi   18
# 1     2     502    alekhya   18
# 2     3     503  vandhitha   17
# 3     4     504    sreemai   19
# 4     5     505   sathwika   20
